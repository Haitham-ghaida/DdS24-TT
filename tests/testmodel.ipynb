# %% [markdown]
# ## run pip install -e . in the root directory to install the package

# %%
import trash

# %%
import trash.mrf_model as mrfmodel
import trash.mrf_model.flow_model as flowmodel

# %%
psd = flowmodel.PlasticSD(year=[2020], verbose=1)

# %%
demands, flows = psd.run()

# %%
demands
# Out:
# [Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=8.414916808474201, spatial_context=GeonamesIRI('https://www.geonames.org/5609855'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=451.8417681169362, spatial_context=GeonamesIRI('https://www.geonames.org/5609855'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=8.12654871504, spatial_context=GeonamesIRI('https://www.geonames.org/5609855'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=61.40337285117744, spatial_context=GeonamesIRI('https://www.geonames.org/5609855'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=52.9676835891, spatial_context=GeonamesIRI('https://www.geonames.org/5609855'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=9.48926055545964, spatial_context=GeonamesIRI('https://www.geonames.org/5609855'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=84.97737119996097, spatial_context=GeonamesIRI('https://www.geonames.org/5609855'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=7.038616935943926, spatial_context=GeonamesIRI('https://www.geonames.org/5609855'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.35931991225365, spatial_context=GeonamesIRI('https://www.geonames.org/5609855'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=74.9454909137721, spatial_context=GeonamesIRI('https://www.geonames.org/5174499'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1868.3893252090754, spatial_context=GeonamesIRI('https://www.geonames.org/5174499'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=90.4715098119, spatial_context=GeonamesIRI('https://www.geonames.org/5174499'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=546.8747970816006, spatial_context=GeonamesIRI('https://www.geonames.org/5174499'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=336.96021511575003, spatial_context=GeonamesIRI('https://www.geonames.org/5174499'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=22.36210248607949, spatial_context=GeonamesIRI('https://www.geonames.org/5174499'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=840.923451914895, spatial_context=GeonamesIRI('https://www.geonames.org/5174499'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=17.703490151861246, spatial_context=GeonamesIRI('https://www.geonames.org/5174499'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=4.2669318199041, spatial_context=GeonamesIRI('https://www.geonames.org/5174499'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=26.895918243083997, spatial_context=GeonamesIRI('https://www.geonames.org/4619773'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=954.1938666673891, spatial_context=GeonamesIRI('https://www.geonames.org/4619773'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=16.233894138, spatial_context=GeonamesIRI('https://www.geonames.org/4619773'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=65.41954537968961, spatial_context=GeonamesIRI('https://www.geonames.org/4619773'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=169.29632458199998, spatial_context=GeonamesIRI('https://www.geonames.org/4619773'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=6.865683668304548, spatial_context=GeonamesIRI('https://www.geonames.org/4619773'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=271.60630108721995, spatial_context=GeonamesIRI('https://www.geonames.org/4619773'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=7.196399839944274, spatial_context=GeonamesIRI('https://www.geonames.org/4619773'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1.1484651842730003, spatial_context=GeonamesIRI('https://www.geonames.org/4619773'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=3.6786722788665003, spatial_context=GeonamesIRI('https://www.geonames.org/4189924'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=208.10936878438542, spatial_context=GeonamesIRI('https://www.geonames.org/4189924'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=5.7729896815499995, spatial_context=GeonamesIRI('https://www.geonames.org/4189924'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=31.317009915126604, spatial_context=GeonamesIRI('https://www.geonames.org/4189924'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=26.463312198, spatial_context=GeonamesIRI('https://www.geonames.org/4189924'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1.767109157755034, spatial_context=GeonamesIRI('https://www.geonames.org/4189924'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=45.4040653925925, spatial_context=GeonamesIRI('https://www.geonames.org/4189924'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=2.323588879313459, spatial_context=GeonamesIRI('https://www.geonames.org/4189924'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.26180100380812504, spatial_context=GeonamesIRI('https://www.geonames.org/4189924'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=16.9955395754559, spatial_context=GeonamesIRI('https://www.geonames.org/4478142'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1222.2069281410043, spatial_context=GeonamesIRI('https://www.geonames.org/4478142'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=24.61968729612, spatial_context=GeonamesIRI('https://www.geonames.org/4478142'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=206.6931611072148, spatial_context=GeonamesIRI('https://www.geonames.org/4478142'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=76.41314509425, spatial_context=GeonamesIRI('https://www.geonames.org/4478142'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=10.221496286901203, spatial_context=GeonamesIRI('https://www.geonames.org/4478142'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=190.697901003705, spatial_context=GeonamesIRI('https://www.geonames.org/4478142'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=7.8100934043466825, spatial_context=GeonamesIRI('https://www.geonames.org/4478142'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.7257155273129251, spatial_context=GeonamesIRI('https://www.geonames.org/4478142'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=7.2505562733615, spatial_context=GeonamesIRI('https://www.geonames.org/5840177'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=354.5602331816425, spatial_context=GeonamesIRI('https://www.geonames.org/5840177'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=5.251566959099999, spatial_context=GeonamesIRI('https://www.geonames.org/5840177'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=44.089226743089, spatial_context=GeonamesIRI('https://www.geonames.org/5840177'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=39.1188151035, spatial_context=GeonamesIRI('https://www.geonames.org/5840177'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=8.176244544766337, spatial_context=GeonamesIRI('https://www.geonames.org/5840177'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=73.21916851598249, spatial_context=GeonamesIRI('https://www.geonames.org/5840177'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=6.064693132712056, spatial_context=GeonamesIRI('https://www.geonames.org/5840177'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.30960130720612505, spatial_context=GeonamesIRI('https://www.geonames.org/5840177'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=7.894231863297299, spatial_context=GeonamesIRI('https://www.geonames.org/5698593'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=567.7010037155358, spatial_context=GeonamesIRI('https://www.geonames.org/5698593'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=10.48259706417, spatial_context=GeonamesIRI('https://www.geonames.org/5698593'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=48.0032931903678, spatial_context=GeonamesIRI('https://www.geonames.org/5698593'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=56.7888375276, spatial_context=GeonamesIRI('https://www.geonames.org/5698593'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=7.5190675149241555, spatial_context=GeonamesIRI('https://www.geonames.org/5698593'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=79.71927550257149, spatial_context=GeonamesIRI('https://www.geonames.org/5698593'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=3.508014526628623, spatial_context=GeonamesIRI('https://www.geonames.org/5698593'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.8988972844266, spatial_context=GeonamesIRI('https://www.geonames.org/5698593'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1.9649044324356002, spatial_context=GeonamesIRI('https://www.geonames.org/4538322'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=88.54984614474404, spatial_context=GeonamesIRI('https://www.geonames.org/4538322'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1.4231773130399996, spatial_context=GeonamesIRI('https://www.geonames.org/4538322'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=7.168921703436959, spatial_context=GeonamesIRI('https://www.geonames.org/4538322'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=10.601218760399998, spatial_context=GeonamesIRI('https://www.geonames.org/4538322'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=2.1760598934173223, spatial_context=GeonamesIRI('https://www.geonames.org/4538322'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=19.842431853798, spatial_context=GeonamesIRI('https://www.geonames.org/4538322'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.1798171736016745, spatial_context=GeonamesIRI('https://www.geonames.org/4538322'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.13983685248449998, spatial_context=GeonamesIRI('https://www.geonames.org/4538322'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=29.664312456549304, spatial_context=GeonamesIRI('https://www.geonames.org/4589213'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1706.6091037341598, spatial_context=GeonamesIRI('https://www.geonames.org/4589213'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=25.066786165889997, spatial_context=GeonamesIRI('https://www.geonames.org/4589213'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=108.22975910522388, spatial_context=GeonamesIRI('https://www.geonames.org/4589213'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=160.04741021369998, spatial_context=GeonamesIRI('https://www.geonames.org/4589213'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=10.497185756032032, spatial_context=GeonamesIRI('https://www.geonames.org/4589213'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=366.13220219183853, spatial_context=GeonamesIRI('https://www.geonames.org/4589213'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=4.378160040916257, spatial_context=GeonamesIRI('https://www.geonames.org/4589213'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1.6889021233052994, spatial_context=GeonamesIRI('https://www.geonames.org/4589213'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=3026.0625601189017, spatial_context=GeonamesIRI('https://www.geonames.org/5128316'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=48358.76181309721, spatial_context=GeonamesIRI('https://www.geonames.org/5128316'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1704.71197740186, spatial_context=GeonamesIRI('https://www.geonames.org/5128316'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=25761.25950209336, spatial_context=GeonamesIRI('https://www.geonames.org/5128316'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=6349.18236481305, spatial_context=GeonamesIRI('https://www.geonames.org/5128316'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=7183.443027611414, spatial_context=GeonamesIRI('https://www.geonames.org/5128316'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=14713.32931690933, spatial_context=GeonamesIRI('https://www.geonames.org/5128316'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=3357.878780160877, spatial_context=GeonamesIRI('https://www.geonames.org/5128316'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=57.428416614806096, spatial_context=GeonamesIRI('https://www.geonames.org/5128316'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=18.563486178400197, spatial_context=GeonamesIRI('https://www.geonames.org/5053853'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1192.567205245271, spatial_context=GeonamesIRI('https://www.geonames.org/5053853'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=35.854680012479996, spatial_context=GeonamesIRI('https://www.geonames.org/5053853'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=338.64287941685154, spatial_context=GeonamesIRI('https://www.geonames.org/5053853'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=116.8478411121, spatial_context=GeonamesIRI('https://www.geonames.org/5053853'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=14.131777289130842, spatial_context=GeonamesIRI('https://www.geonames.org/5053853'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=187.461895542291, spatial_context=GeonamesIRI('https://www.geonames.org/5053853'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=14.09327373390441, spatial_context=GeonamesIRI('https://www.geonames.org/5053853'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1.5853347992762998, spatial_context=GeonamesIRI('https://www.geonames.org/5053853'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=37.5880031569146, spatial_context=GeonamesIRI('https://www.geonames.org/4754972'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1729.9717557314539, spatial_context=GeonamesIRI('https://www.geonames.org/4754972'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=90.7497797388, spatial_context=GeonamesIRI('https://www.geonames.org/4754972'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=502.84378871816233, spatial_context=GeonamesIRI('https://www.geonames.org/4754972'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=270.39730289519997, spatial_context=GeonamesIRI('https://www.geonames.org/4754972'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=20.32832899617003, spatial_context=GeonamesIRI('https://www.geonames.org/4754972'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=463.93046836979704, spatial_context=GeonamesIRI('https://www.geonames.org/4754972'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=6.019680464946556, spatial_context=GeonamesIRI('https://www.geonames.org/4754972'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1.60502097685995, spatial_context=GeonamesIRI('https://www.geonames.org/4754972'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=10.566148385364897, spatial_context=GeonamesIRI('https://www.geonames.org/4678446'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=415.3833483379403, spatial_context=GeonamesIRI('https://www.geonames.org/4678446'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=15.306090637319995, spatial_context=GeonamesIRI('https://www.geonames.org/4678446'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=38.55041966986884, spatial_context=GeonamesIRI('https://www.geonames.org/4678446'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=85.51106759114998, spatial_context=GeonamesIRI('https://www.geonames.org/4678446'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=6.582433150347377, spatial_context=GeonamesIRI('https://www.geonames.org/4678446'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
# ...
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.28560681280305, spatial_context=GeonamesIRI('https://www.geonames.org/4781725'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=10.887986180332799, spatial_context=GeonamesIRI('https://www.geonames.org/4744616'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=501.11490334131076, spatial_context=GeonamesIRI('https://www.geonames.org/4744616'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=26.287173158399998, spatial_context=GeonamesIRI('https://www.geonames.org/4744616'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=145.65701188152576, spatial_context=GeonamesIRI('https://www.geonames.org/4744616'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=78.32504655359999, spatial_context=GeonamesIRI('https://www.geonames.org/4744616'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=5.88843637837254, spatial_context=GeonamesIRI('https://www.geonames.org/4744616'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=134.385125678496, spatial_context=GeonamesIRI('https://www.geonames.org/4744616'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1.743699909749008, spatial_context=GeonamesIRI('https://www.geonames.org/4744616'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.4649208456816001, spatial_context=GeonamesIRI('https://www.geonames.org/4744616'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=68.43287850896401, spatial_context=GeonamesIRI('https://www.geonames.org/4856473'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1128.6044953972798, spatial_context=GeonamesIRI('https://www.geonames.org/4856473'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=14.869749167279998, spatial_context=GeonamesIRI('https://www.geonames.org/4856473'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=349.5467340917194, spatial_context=GeonamesIRI('https://www.geonames.org/4856473'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=86.15013406439999, spatial_context=GeonamesIRI('https://www.geonames.org/4856473'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=61.55078294016734, spatial_context=GeonamesIRI('https://www.geonames.org/4856473'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=168.92675700819598, spatial_context=GeonamesIRI('https://www.geonames.org/4856473'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=15.841051975812233, spatial_context=GeonamesIRI('https://www.geonames.org/4856473'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.7792288055688, spatial_context=GeonamesIRI('https://www.geonames.org/4856473'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=48.872210695812, spatial_context=GeonamesIRI('https://www.geonames.org/5147012'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=1218.3830628113776, spatial_context=GeonamesIRI('https://www.geonames.org/5147012'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=58.99678066799999, spatial_context=GeonamesIRI('https://www.geonames.org/5147012'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=356.6189237181984, spatial_context=GeonamesIRI('https://www.geonames.org/5147012'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=219.73290759, spatial_context=GeonamesIRI('https://www.geonames.org/5147012'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=14.582403437165127, spatial_context=GeonamesIRI('https://www.geonames.org/5147012'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=548.3690562294, spatial_context=GeonamesIRI('https://www.geonames.org/5147012'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=11.544506416649588, spatial_context=GeonamesIRI('https://www.geonames.org/5147012'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=2.7824808188520005, spatial_context=GeonamesIRI('https://www.geonames.org/5147012'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=6.9950008617965995, spatial_context=GeonamesIRI('https://www.geonames.org/4917993'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/760200110010>: Waste (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=301.82055042206326, spatial_context=GeonamesIRI('https://www.geonames.org/4917993'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470710000080>: Unbleached kraft paper or paperboard or corrugated paper or paperboard (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=15.19940568132, spatial_context=GeonamesIRI('https://www.geonames.org/4917993'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/720400000080>: 7204 Ferrous waste and scrap; remelting scrap ingots of iron or steel (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=93.57753644823673, spatial_context=GeonamesIRI('https://www.geonames.org/4917993'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/700100000080>: 7001 00 Cullet and other waste and scrap of glass, excluding glass from cathode-ray tubes or other activated glass of heading 8549; glass in the mass (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=44.0300243943, spatial_context=GeonamesIRI('https://www.geonames.org/4917993'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510200080>: Having a specific gravity of 0,94 or more (for example, PE-HD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=9.645197296698589, spatial_context=GeonamesIRI('https://www.geonames.org/4917993'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/470730000080>: Paper or paperboard made mainly of mechanical pulp (for example, newspapers, journals and similar printed matter) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=78.48718047116999, spatial_context=GeonamesIRI('https://www.geonames.org/4917993'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/391510100080>: Having a specific gravity of less than 0,94 (for example, PE-LD) (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=6.720127885353577, spatial_context=GeonamesIRI('https://www.geonames.org/4917993'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/xsp/cn2024/392010230080>: Polyethylene film, of a thickness of 20 micrometres or more but not exceeding 40 micrometres, for the production of photoresist film used in the manufacture of semiconductors or printed circuits (product)),
#  Demand(unit_iri=<https://vocab.sentier.dev/units/unit/KiloGM>: kilogram (unit), amount=0.7965040029372001, spatial_context=GeonamesIRI('https://www.geonames.org/4917993'), properties=None, begin_date=datetime.date(2020, 1, 1), end_date=datetime.date(2020, 12, 31), product_iri=<http://data.europa.eu/ehl/cpa21/381131>: Missing label (product))]
